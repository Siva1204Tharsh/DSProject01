# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %%
print("Hello Data Science")
# Out:
# Hello Data Science

# %%
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))

if num1>num2:
    print("The first number is greater than the second number")
elif num1<num2:
    print("The first number is less than the second number")
else:
    print("The first number is equal to the second number")
# Out:
# The first number is less than the second number

# %% [markdown]
# # Problem Statement

# %% [markdown]
# for a real estate startup they want to include house price prediction feature for their applicatio n users for a particular area.

# %% [markdown]
# 3.Data Cleaning

# %% [markdown]
# 4.Data Analysis

# %% [markdown]
# Using Pandas library to read the CSV file

# %%
df=pd.read_csv('Data01.csv')
df.head()
# Out:
#    sq ft    price
# 0    850  4500000
# 1    960  5200000
# 2   1000  5400000
# 3   1250  5900000
# 4   1500  6200000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df['price'],df['sq ft'])

# %%
plt.scatter(df['price'] ,df['sq ft'])
plt.xlabel('Price')
plt.ylabel('Area')
plt.title('Price VS Area')
plt.plot(df['price'] ,df['sq ft'])

# %% [markdown]
# 5.Building ML Model

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()

# %%
df
# Out:
#    sq ft    price
# 0    850  4500000
# 1    960  5200000
# 2   1000  5400000
# 3   1250  5900000
# 4   1500  6200000
# 5   1650  6500000

# %%
X=df.drop('price',axis='columns')
X
# Out:
#    sq ft
# 0    850
# 1    960
# 2   1000
# 3   1250
# 4   1500
# 5   1650

# %%
y=df.price
y
# Out:
# 0    4500000
# 1    5200000
# 2    5400000
# 3    5900000
# 4    6200000
# 5    6500000
# Name: price, dtype: int64

# %% [markdown]
# Training the algorithm using fit()
# =======================

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[1100]])
# Out:
# c:\Users\SIVA1201\miniconda3\envs\datascience\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5395437.63145122])

# %%
ytest=model.predict(X)
ytest
# Out:
# array([4851431.80715095, 5090794.36984307, 5177835.30173111,
#        5721841.12603139, 6265846.95033166, 6592250.44491183])

# %%
plt.scatter(df['price'] ,df['sq ft'])
plt.xlabel('Price')
plt.ylabel('Area')
plt.title('Price VS Area')
plt.plot(ytest  ,df['sq ft'])

# %% [markdown]
# #  y=mX+b

# %%
m=model.coef_
m
# Out:
# array([2176.0232972])

# %%
b=model.intercept_
b
# Out:
# 3001812.0045300107

# %% [markdown]
# Downloaeding the Model using pickle

# %%
import pickle

# %%
with open('myFM01','wb') as file:
  pickle.dump(model,file)
